# %%
import numpy as np
import matplotlib.pyplot as plt
  
data = load_breast_cancer()
X = data.data
y = data.target
X.data.shape

l1 = LR(penalty="l1",solver="liblinear",C=0.5,max_iter=2000)
l1 = l1.fit(X,y)
l1.coef_

l2 = LR(penalty="l2",solver="liblinear",C=0.5,max_iter=2000)
l2 = l2.fit(X,y)
l2.coef_
# Out:
# array([[ 1.61429317e+00,  1.00806312e-01,  5.06059885e-02,
#         -4.62973042e-03, -9.57138795e-02, -3.01143381e-01,
#         -4.57926003e-01, -2.24732123e-01, -1.37854324e-01,
#         -1.93377451e-02,  1.38239537e-02,  8.84896425e-01,
#          1.12259291e-01, -9.40136337e-02, -1.00419390e-02,
#         -2.16087298e-02, -5.55281434e-02, -2.72481333e-02,
#         -2.79859322e-02,  5.37904915e-04,  1.24301708e+00,
#         -3.00470821e-01, -1.71767501e-01, -2.20475199e-02,
#         -1.76237700e-01, -8.75625922e-01, -1.16399898e+00,
#         -4.32246448e-01, -4.26963910e-01, -8.66660769e-02]])
